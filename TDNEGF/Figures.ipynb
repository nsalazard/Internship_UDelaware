# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("./MT.out" )
# = np.loadtxt("./data/spj_eqTe231.4.txt" )

# %%
plt.plot(data[:,0],data[:,1])
plt.plot(data[:,0],data[:,2])

# %%
data[:,0].size
# Out:
# 10000

# %%
### exp 1 is with both 
name1="pump_freq_02_exp1" 
name2="pump_freq_04_exp1" 
name3="pump_freq_06_exp1" 
name4="pump_freq_08_exp1" 
name5="pump_freq_1_exp1" 


name21="pump_freq_02_exp2" 
name22="pump_freq_04_exp2" 
name23="pump_freq_06_exp2" 
name24="pump_freq_08_exp2" 
name25="pump_freq_1_exp2" 

name31="pump_freq_02_exp3" 
name32="pump_freq_04_exp3" 
name33="pump_freq_06_exp3" 
name34="pump_freq_08_exp3" 
name35="pump_freq_1_exp3" 


name41="pump_freq_02_exp4" 
name42="pump_freq_04_exp4" 
name43="pump_freq_06_exp4" 
name44="pump_freq_08_exp4" 
name45="pump_freq_1_exp4" 
### with exp 2 there are a symm breacking.
names = ([name1, name2, name3, name4, name5] +  [name21, name22, name23, name24, name25]
         +[name31, name32, name33, name34, name35]+ [name41, name42, name43, name44, name45] )
#names = [name21, name22, name23, name24, name25]
data = {}

# %%
chj_exp2 = np.loadtxt("./data/chj_eqTe231.4.txt" )
spj_exp2 = np.loadtxt("./data/spj_eqTe231.4.txt" )

# %%
plt.plot(chj_exp2[:,0],chj_exp2[:,1])
#plt.plot(chj_exp2[:,0],chj_exp2[:,2])
#plt.plot(chj_exp2[:,0],chj_exp2[:,3])

# %%
for name in names: 
    data[f"cspins_f_{name}"] = np.loadtxt(f"./data/cspins_{name}_jl.txt" )
    data[f"seq_f_{name}"] = np.loadtxt(f"./data/seq_{name}_jl.txt" ) 
    data[f"sneq_f_{name}"] = np.loadtxt(f"./data/sneq_{name}_jl.txt" )
    data[f"seq_f_{name}"] = np.loadtxt(f"./data/seq_{name}_jl.txt" )
    data[f"sc_f_{name}"] = np.loadtxt(f"./data/sc_{name}_jl.txt" )
    data[f"cc_f_{name}"] = np.loadtxt(f"./data/cc_{name}_jl.txt" ) ;

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"sneq_f_{name1}"][:,0],data[f"sneq_f_{name1}"][:,13])
axs.plot(data[f"sneq_f_{name1}"][:,0],data[f"sneq_f_{name1}"][:,14])
axs.plot(data[f"sneq_f_{name1}"][:,0],data[f"sneq_f_{name1}"][:,15])

# %%
#### Charge current 
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"cc_f_{name1}"][:,0],data[f"cc_f_{name1}"][:,1])
axs.plot(data[f"cc_f_{name1}"][:,0],data[f"cc_f_{name1}"][:,2])
axs.plot(data[f"cc_f_{name1}"][:,0],data[f"cc_f_{name1}"][:,3])


axs.set_ylim([-1e-2,1e-2])
# Out:
# (-0.01, 0.01)

# %%
#### Charge current 
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"cc_f_{name21}"][:,0],data[f"cc_f_{name21}"][:,1])
plt.plot(chj_exp2[:,0],chj_exp2[:,1])
plt.plot(chj_exp2[:,0],chj_exp2[:,2])
plt.plot(chj_exp2[:,0],chj_exp2[:,3])
axs.plot(data[f"cc_f_{name21}"][:,0],data[f"cc_f_{name21}"][:,2])
axs.plot(data[f"cc_f_{name21}"][:,0],data[f"cc_f_{name21}"][:,3],ls = ':')
axs.set_ylim([-1e-3,3e-3])
# Out:
# (-0.001, 0.003)

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"cc_f_{name1}"][:,0],data[f"cc_f_{name1}"][:,1])
axs.plot(data[f"cc_f_{name2}"][:,0],data[f"cc_f_{name2}"][:,1])
axs.plot(data[f"cc_f_{name3}"][:,0],data[f"cc_f_{name3}"][:,1])
axs.plot(data[f"cc_f_{name4}"][:,0],data[f"cc_f_{name4}"][:,1])
axs.plot(data[f"cc_f_{name5}"][:,0],data[f"cc_f_{name5}"][:,1])
axs.set_ylim([-1e-3,1e-3])
# Out:
# (-0.001, 0.001)

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"cc_f_{name1}"][:,0],data[f"cc_f_{name1}"][:,1])
axs.plot(data[f"cc_f_{name2}"][:,0],data[f"cc_f_{name2}"][:,1])
axs.plot(data[f"cc_f_{name3}"][:,0],data[f"cc_f_{name3}"][:,1])
axs.plot(data[f"cc_f_{name4}"][:,0],data[f"cc_f_{name4}"][:,1])
axs.plot(data[f"cc_f_{name5}"][:,0],data[f"cc_f_{name5}"][:,1])
axs.set_ylim([-1e-3,1e-2])
axs.set_xlim([800,1000])
axs.set_ylim([0,3e-4])
# Out:
# (0.0, 0.0003)

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"cc_f_{name31}"][:,0],data[f"cc_f_{name31}"][:,1])
axs.plot(data[f"cc_f_{name32}"][:,0],data[f"cc_f_{name32}"][:,1])
axs.plot(data[f"cc_f_{name33}"][:,0],data[f"cc_f_{name33}"][:,1])
axs.plot(data[f"cc_f_{name34}"][:,0],data[f"cc_f_{name34}"][:,1])
axs.plot(data[f"cc_f_{name35}"][:,0],data[f"cc_f_{name35}"][:,1])
axs.set_ylim([-1e-3,1e-3])
axs.set_xlim([1800,2000])
axs.set_ylim([-1e-8,1e-8])
# Out:
# (-1e-08, 1e-08)

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"cc_f_{name41}"][:,0],data[f"cc_f_{name41}"][:,1])
axs.plot(data[f"cc_f_{name42}"][:,0],data[f"cc_f_{name42}"][:,1])
axs.plot(data[f"cc_f_{name43}"][:,0],data[f"cc_f_{name43}"][:,1])
axs.plot(data[f"cc_f_{name44}"][:,0],data[f"cc_f_{name44}"][:,1])
axs.plot(data[f"cc_f_{name45}"][:,0],data[f"cc_f_{name45}"][:,1])
axs.set_ylim([-1e-3,1e-3])
axs.set_xlim([1800,2000])
axs.set_ylim([-1e-8,1e-8])
# Out:
# (-1e-08, 1e-08)

# %%
#fig,axs = plt.subplots(1,1)


W1,F1 = fourier_transform(data[f"cc_f_{name41}"][10000:20000,0], data[f"cc_f_{name41}"][10000:20000,2], 0.1)
W2,F2 = fourier_transform(data[f"cc_f_{name42}"][10000:20000,0], data[f"cc_f_{name42}"][10000:20000,2], 0.1)
W3,F3 = fourier_transform(data[f"cc_f_{name43}"][10000:20000,0], data[f"cc_f_{name43}"][10000:20000,2], 0.1)
W4,F4 = fourier_transform(data[f"cc_f_{name44}"][10000:20000,0], data[f"cc_f_{name44}"][10000:20000,2], 0.1)
W5,F5 = fourier_transform(data[f"cc_f_{name45}"][10000:20000,0], data[f"cc_f_{name45}"][10000:20000,2], 0.1)



W1 = W1[::1]*2*np.pi 
W2 = W2[::1]*2*np.pi 
W3 = W3[::1]*2*np.pi 
W4 = W4[::1]*2*np.pi 
W5 = W5[::1]*2*np.pi 
fig,axs = plt.subplots(1,1)
axs.plot(W1,F1)
axs.plot(W2,F2)
axs.plot(W3,F3)
axs.plot(W4,F4)
axs.plot(W5,F5)
#axs.set_xlim([-1e-3,1.2])
axs.set_yscale('log')

# %%
#fig,axs = plt.subplots(1,1)


W1,F1 = fourier_transform(data[f"cc_f_{name31}"][10000:20000,0], data[f"cc_f_{name31}"][10000:20000,3], 0.1)
W2,F2 = fourier_transform(data[f"cc_f_{name32}"][10000:20000,0], data[f"cc_f_{name32}"][10000:20000,3], 0.1)
W3,F3 = fourier_transform(data[f"cc_f_{name33}"][10000:20000,0], data[f"cc_f_{name33}"][10000:20000,3], 0.1)
W4,F4 = fourier_transform(data[f"cc_f_{name34}"][10000:20000,0], data[f"cc_f_{name34}"][10000:20000,3], 0.1)
W5,F5 = fourier_transform(data[f"cc_f_{name35}"][10000:20000,0], data[f"cc_f_{name35}"][10000:20000,3], 0.1)



W1 = W1[::1]*2*np.pi 
W2 = W2[::1]*2*np.pi 
W3 = W3[::1]*2*np.pi 
W4 = W4[::1]*2*np.pi 
W5 = W5[::1]*2*np.pi 
fig,axs = plt.subplots(1,1)
axs.plot(W1,F1)
axs.plot(W2,F2)
axs.plot(W3,F3)
axs.plot(W4,F4)
axs.plot(W5,F5)
#axs.set_xlim([-1e-3,1.2])
axs.set_yscale('log')

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"sc_f_{name31}"][:,0],data[f"sc_f_{name31}"][:,1])
axs.plot(data[f"sc_f_{name31}"][:,0],data[f"sc_f_{name31}"][:,2])
axs.plot(data[f"sc_f_{name31}"][:,0],data[f"sc_f_{name31}"][:,3])
#axs.plot(data[f"sc_f_{name34}"][:,0],data[f"sc_f_{name34}"][:,6])
#axs.plot(data[f"sc_f_{name35}"][:,0],data[f"sc_f_{name35}"][:,6])

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"sc_f_{name41}"][:,0],data[f"sc_f_{name41}"][:,4])
axs.plot(data[f"sc_f_{name41}"][:,0],data[f"sc_f_{name41}"][:,5])
axs.plot(data[f"sc_f_{name41}"][:,0],data[f"sc_f_{name41}"][:,6])

# %%
fig,axs = plt.subplots(1,1)

axs.plot(data[f"sc_f_{name41}"][:,0],data[f"sc_f_{name41}"][:,3],alpha=0.8)


axs.plot(data[f"sc_f_{name42}"][:,0],data[f"sc_f_{name42}"][:,3],alpha=0.8)

#axs.plot(data[f"sc_f_{name33}"][:,0],data[f"sc_f_{name33}"][:,3])
axs.plot(data[f"sc_f_{name43}"][:,0],data[f"sc_f_{name43}"][:,3],alpha=0.8)

#axs.plot(data[f"sc_f_{name34}"][:,0],data[f"sc_f_{name34}"][:,3])
axs.plot(data[f"sc_f_{name44}"][:,0],data[f"sc_f_{name44}"][:,3],alpha=0.8)

axs.plot(data[f"sc_f_{name45}"][:,0],data[f"sc_f_{name45}"][:,3],alpha=0.8)

axs.set_xlim([1800,2000])

axs.set_ylim([-2e-2,0.0])
# Out:
# (-0.02, 0.0)

# %%
def fourier_transform(times,data,dt):
    """ This function calculates the FFT tranformation of a set of data
    """
    from scipy.fft import fft, fftfreq ### Import functions to make the FFT
    
    N = times.size                     ### Calculate the size of the data set
    # This computes the complex Fourier coeffients, representing
    #  the amplitude and phase information for each frquency
    yif = np.fft.fft(data)             ### Apply the FFT algorithm to the data 
    yf = abs(yif[0:N//2])              ### We only consider the first half of the spectrum
                                       ### since the FFT output is symmetric due to the propt.
                                       ### of real input signals
    yf= (2/N)*yf                       ### Normalice the amplitudes and the factor of two 
                                       ### accounts for the symmetry in the spectrum are properly scaled 
    # This Calculates the optimal frequencies based on the number of data points and the time interval 
    # between consecutive points
    xf = np.fft.fftfreq(N,dt)[0:N//2]  ### Generates the correspoding frqeuncy values for each data point 
    
    return xf, yf

# %%
W1,F1 = fourier_transform(data[f"sc_f_{name31}"][10000:20000,0], data[f"sc_f_{name31}"][10000:20000,3], 0.1)
W2,F2 = fourier_transform(data[f"sc_f_{name32}"][10000:20000,0], data[f"sc_f_{name32}"][10000:20000,3], 0.1)
W3,F3 = fourier_transform(data[f"sc_f_{name33}"][10000:20000,0], data[f"sc_f_{name33}"][10000:20000,3], 0.1)
W4,F4 = fourier_transform(data[f"sc_f_{name34}"][10000:20000,0], data[f"sc_f_{name34}"][10000:20000,3], 0.1)
W5,F5 = fourier_transform(data[f"sc_f_{name35}"][10000:20000,0], data[f"sc_f_{name35}"][10000:20000,3], 0.1)
#W1 = W1[::1]*T1 
W1 = W1[::1]*2*np.pi 
W2 = W2[::1]*2*np.pi 
W3 = W3[::1]*2*np.pi 
W4 = W4[::1]*2*np.pi 
W5 = W5[::1]*2*np.pi 
fig,axs = plt.subplots(1,1)
axs.plot(W1,F1)
axs.plot(W2,F2)
axs.plot(W3,F3)
axs.plot(W4,F4)
axs.plot(W5,F5)
axs.set_xlim([-1e-3,1.2])
axs.set_yscale('log')

# %%
W1,F1 = fourier_transform(data[f"sc_f_{name41}"][10000:20000,0], data[f"sc_f_{name41}"][10000:20000,6], 0.1)
W2,F2 = fourier_transform(data[f"sc_f_{name42}"][10000:20000,0], data[f"sc_f_{name42}"][10000:20000,6], 0.1)
W3,F3 = fourier_transform(data[f"sc_f_{name43}"][10000:20000,0], data[f"sc_f_{name43}"][10000:20000,6], 0.1)
W4,F4 = fourier_transform(data[f"sc_f_{name44}"][10000:20000,0], data[f"sc_f_{name44}"][10000:20000,6], 0.1)
W5,F5 = fourier_transform(data[f"sc_f_{name45}"][10000:20000,0], data[f"sc_f_{name45}"][10000:20000,6], 0.1)
W1 = W1[::1]*2*np.pi 
W2 = W2[::1]*2*np.pi 
W3 = W3[::1]*2*np.pi 
W4 = W4[::1]*2*np.pi 
W5 = W5[::1]*2*np.pi 
fig,axs = plt.subplots(1,1)
axs.plot(W1,F1)
axs.plot(W2,F2)
axs.plot(W3,F3)
axs.plot(W4,F4)
axs.plot(W5,F5)
axs.set_xlim([-1e-3,1.2])
axs.set_yscale('log')

# %%
fig,axs = plt.subplots(1,1)

axs.plot(data[f"sc_f_{name31}"][:,0],data[f"sc_f_{name31}"][:,3],alpha=0.8)


axs.plot(data[f"sc_f_{name32}"][:,0],data[f"sc_f_{name32}"][:,3],alpha=0.8)

#axs.plot(data[f"sc_f_{name33}"][:,0],data[f"sc_f_{name33}"][:,3])
axs.plot(data[f"sc_f_{name33}"][:,0],data[f"sc_f_{name33}"][:,3],alpha=0.8)

#axs.plot(data[f"sc_f_{name34}"][:,0],data[f"sc_f_{name34}"][:,3])
#axs.plot(data[f"sc_f_{name34}"][:,0],data[f"sc_f_{name34}"][:,3],alpha=0.8)

#axs.plot(data[f"sc_f_{name35}"][:,0],data[f"sc_f_{name35}"][:,3],alpha=0.8)

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"sc_f_{name31}"][:,0],data[f"sc_f_{name31}"][:,4])
axs.plot(data[f"sc_f_{name32}"][:,0],data[f"sc_f_{name32}"][:,5])
axs.plot(data[f"sc_f_{name33}"][:,0],data[f"sc_f_{name33}"][:,6])

# %%
np.shape(data[f"sc_f_{name1}"] )#[:,1]
# Out:
# (10000, 7)

# %%
#### Spin current  
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"sc_f_{name1}"][:,0],data[f"sc_f_{name1}"][:,4])
axs.plot(data[f"sc_f_{name1}"][:,0],data[f"sc_f_{name1}"][:,5])
axs.plot(data[f"sc_f_{name1}"][:,0],data[f"sc_f_{name1}"][:,6])
#axs.set_ylim([-1e-2,1e-2])

# %%
fig,axs = plt.subplots(1,1)
#plt.plot(data[f"cspins_f_{name1}"][:,0],data[f"cspins_f_{name1}"][:,13])
axs.plot(data[f"sc_f_{name21}"][:,0],data[f"sc_f_{name21}"][:,4])
axs.plot(data[f"sc_f_{name21}"][:,0],data[f"sc_f_{name21}"][:,5])
#axs.plot(data[f"sc_f_{name21}"][:,0],data[f"sc_f_{name21}"][:,3])
axs.plot(data[f"sc_f_{name21}"][:,0],data[f"sc_f_{name21}"][:,6])
#axs.set_ylim([-1e-2,1e-2])

# %%
#### Spin current  S_z in the right lead 
fig,axs = plt.subplots(1,1)
axs.plot(data[f"sc_f_{name1}"][:,0],data[f"sc_f_{name1}"][:,6])
axs.plot(data[f"sc_f_{name2}"][:,0],data[f"sc_f_{name2}"][:,6])
axs.plot(data[f"sc_f_{name3}"][:,0],data[f"sc_f_{name3}"][:,6])
axs.plot(data[f"sc_f_{name4}"][:,0],data[f"sc_f_{name4}"][:,6])
axs.plot(data[f"sc_f_{name5}"][:,0],data[f"sc_f_{name5}"][:,6])
axs.set_ylim([-0.32,0.0])
#axs.set_ylim([-0.11,-0.12])
# Out:
# (-0.32, 0.0)

# %%
fig,axs = plt.subplots(1,1)
axs.plot(data[f"sc_f_{name1}"][:,0],data[f"sc_f_{name1}"][:,3])
axs.plot(data[f"sc_f_{name2}"][:,0],data[f"sc_f_{name2}"][:,3])
axs.plot(data[f"sc_f_{name3}"][:,0],data[f"sc_f_{name3}"][:,3])
axs.plot(data[f"sc_f_{name4}"][:,0],data[f"sc_f_{name4}"][:,3])

# %%
#### Spin current  S_z in the right lead 
fig,axs = plt.subplots(1,1)


axs.plot(data[f"sc_f_{name21}"][:,0],data[f"sc_f_{name21}"][:,6])
plt.plot(spj_exp2[:,0],spj_exp2[:,6] )
#axs.plot(data[f"sc_f_{name21}"][:,0],data[f"sc_f_{name21}"][:,3])
# axs.plot(data[f"sc_f_{name22}"][:,0],data[f"sc_f_{name22}"][:,6])
# axs.plot(data[f"sc_f_{name22}"][:,0],data[f"sc_f_{name22}"][:,3])
# axs.plot(data[f"sc_f_{name23}"][:,0],data[f"sc_f_{name23}"][:,6])
# axs.plot(data[f"sc_f_{name23}"][:,0],data[f"sc_f_{name23}"][:,3])
##axs.plot(data[f"sc_f_{name24}"][:,0],data[f"sc_f_{name24}"][:,6])
##axs.plot(data[f"sc_f_{name25}"][:,0],data[f"sc_f_{name25}"][:,6])
axs.set_ylim([-0.42,0.0])
# Out:
# (-0.42, 0.0)

# %%
#### Spin current  S_z in the left lead 
#fig,axs = plt.subplots(1,1)
#axs.plot(data[f"sc_f_{name1}"][:,0],data[f"sc_f_{name1}"][:,1])
#axs.plot(data[f"sc_f_{name2}"][:,0],data[f"sc_f_{name2}"][:,3])
#axs.plot(data[f"sc_f_{name3}"][:,0],data[f"sc_f_{name3}"][:,3])
#axs.plot(data[f"sc_f_{name4}"][:,0],data[f"sc_f_{name4}"][:,3])
#axs.plot(data[f"sc_f_{name5}"][:,0],data[f"sc_f_{name5}"][:,3])
#axs.set_ylim([-0.32,0.0])

# %%
plt.plot(spj_exp2[:,0],spj_exp2[:,5] )
#plt.plot(spj_exp2[:,0],spj_exp2[:,5] )
plt.plot(spj_exp2[:,0],spj_exp2[:,6] )
