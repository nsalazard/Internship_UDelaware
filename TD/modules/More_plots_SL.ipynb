# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
rcParams['axes.linewidth']=2
rcParams['text.usetex']=True#True
path = "/home/jalil/Projects2023/TDNEGF/TDNEGF/data/"

# %%
def fourier_transform(times,data,dt):
    """ This function calculates the FFT tranformation of a set of data
    """
    from scipy.fft import fft, fftfreq ### Import functions to make the FFT
    N = times.size                     ### Calculate the size of the data set
    # This computes the complex Fourier coeffients, representing
    #  the amplitude and phase information for each frquency
    yif = np.fft.fft(data)             ### Apply the FFT algorithm to the data 
    yf = abs(yif[0:N//2])              ### We only consider the first half of the spectrum
                                       ### since the FFT output is symmetric due to the propt.
                                       ### of real input signals
    yf= (2/N)*yf                       ### Normalice the amplitudes and the factor of two 
                                       ### accounts for the symmetry in the spectrum are properly scaled 
    # This Calculates the optimal frequencies based on the number of data points and the time interval 
    # between consecutive points
    xf = np.fft.fftfreq(N,dt)[0:N//2]  ### Generates the correspoding frqeuncy values for each data point 
    return xf, yf

# %%
# ### Experiment 1
# name1 =  "ferropumpT5J1t100"
# name2 = "aferropumpT5J1t100"
# name3 = "slpumpT5J1t100"
# ### Experiment 2
# name1 =  "ferropumpT5J05t100"
# name2 = "aferropumpT5J05t100"
# name3 = "slpumpT5J05t100"
# ### Experiment 3
# name1 =  "ferropumpT5J15t100"
# name2 = "aferropumpT5J15t100"
# name3 = "slpumpT5J15t100"
# ### Experiment 4
# name1 =  "ferropumpT5Jsd01J01t100"
# name2 = "aferropumpT5Jsd01J01t100"
# name3 = "slpumpT5Jsd01J01t100"
### Experiment 5
# name1 = "ferropulsesmBiasv04a30Jsd01J01t100"
# name2 = "aferropulsesmBiasv04a30Jsd01J01t100"
# name3 = "slpulsesmBiasv04a30Jsd01J01t100"
### Experiment 6
#name1 = "ferropulsesmBiasv002a30Jsd01J01t100"
#name2 = "aferropulsesmBiasv002a30Jsd01J01t100"
#name3 = "slpulsesmBiasv002a30Jsd01J01t100"
### Experiment 7
# name1 = "ferropulsesmBeamv002a100Jsd01J01Pol05t100"
# name2 = "aferropulsesmBeamv002a100Jsd01J01Pol05t100"
# name3 = "slpulsesmBeamv002a100Jsd01J01Pol05t100"
### Experiment 8
# name1 = "ferropulsesmBeamv002a100Jsd01J01Pol1t200"
# name2 = "aferropulsesmBeamv002a100Jsd01J01Pol1t200"
# name3 = "slpulsesmBeamv002a100Jsd01J01Pol1t200"
### Experiment 9
# name1 = "ferropulsesmLevitonv002a100Jsd01J01Pol1t200"
# name2 = "aferropulsesmLevitonv002a100Jsd01J01Pol1t200"
# name3 = "slpulsesmLevitonv002a100Jsd01J01Pol1t200"
### Experiment 10
# name1 = "ferropulsesmLevitonv002a100Jsd1J01Pol1t200"
# name2 = "aferropulsesmLevitonv002a100Jsd1J01Pol1t200"
# name3 = "slpulsesmLevitonv002a100Jsd01J1Pol1t200"
### Experiment 11
name1 = "ferropulsesmLevitonvr002a100Jsd1J01Pol1t200"
name2 = "aferropulsesmLevitonvr002a100Jsd1J01Pol1t200"
name3 = "slpulsesmLevitonvr002a100Jsd01J1Pol1t200"

# %%
### Charge current
cc_ferro = np.loadtxt(path+f"cc_{name1}_sl_jl.txt")
cc_afi  = np.loadtxt(path+f"cc_{name2}_sl_jl.txt")
cc_sl = np.loadtxt(path+f"cc_{name3}_sl_jl.txt")
# ### Spin current 
sc_ferro= np.loadtxt(path+f"sc_{name1}_sl_jl.txt")
sc_afi= np.loadtxt(path+f"sc_{name2}_sl_jl.txt")
sc_sl= np.loadtxt(path+f"sc_{name3}_sl_jl.txt")
# ### Spin density 
#sd_ferro = np.loadtxt(path+f"sden_{name1}_sl_jl.txt")
#sd_afi = np.loadtxt(path+f"sden_{name2}_sl_jl.txt")
#sd_sl = np.loadtxt(path+f"sden_{name3}_sl_jl.txt")
# ### Entropy
ent_ferro = np.loadtxt(path+f"entropy_{name1}_sl_jl.txt")
ent_afi = np.loadtxt(path+f"entropy_{name2}_sl_jl.txt")
ent_sl = np.loadtxt(path+f"entropy_{name3}_sl_jl.txt")

# %%
# ### Charge current
# cc_ferro = np.loadtxt(path+"cc_ferropumpT5J05t100_sl_jl.txt")
# cc_afi  = np.loadtxt(path+"cc_aferropumpT5J05t100_sl_jl.txt")
# cc_sl = np.loadtxt(path+"cc_slpumpT5J05t100_sl_jl.txt")
# # ### Spin current 
# sc_ferro= np.loadtxt(path+"sc_ferropumpT5J05t100_sl_jl.txt")
# sc_afi= np.loadtxt(path+"sc_aferropumpT5J05t100_sl_jl.txt")
# sc_sl= np.loadtxt(path+"sc_slpumpT5J05t100_sl_jl.txt")
# # ### Spin density 
# # sd_ferro = np.loadtxt("sden_ferropumpT5J05_sl_jl.txt")
# # sd_afi = np.loadtxt("sden_aferropumpT5J05_sl_jl.txt")
# # sd_sl = np.loadtxt("sden_slpumpT5J05_sl_jl.txt")
# # ### Entropy
# ent_ferro = np.loadtxt(path+"entropy_ferropumpT5J05t100_sl_jl.txt")
# ent_afi = np.loadtxt(path+"entropy_aferropumpT5J05t100_sl_jl.txt")
# ent_sl = np.loadtxt(path+"entropy_slpumpT5J05t100_sl_jl.txt")

# %%
# ### Charge current
# cc_ferro = np.loadtxt(path+"cc_ferropumpT5J15t100_sl_jl.txt")
# cc_afi  = np.loadtxt(path+"cc_aferropumpT5J15t100_sl_jl.txt")
# cc_sl = np.loadtxt(path+"cc_slpumpT5J15t100_sl_jl.txt")
# # ### Spin current 
# sc_ferro= np.loadtxt(path+"sc_ferropumpT5J15t100_sl_jl.txt")
# sc_afi= np.loadtxt(path+"sc_aferropumpT5J15t100_sl_jl.txt")
# sc_sl= np.loadtxt(path+"sc_slpumpT5J15t100_sl_jl.txt")
# # ### Spin density 
# # sd_ferro = np.loadtxt(path+"sden_ferropumpT5J15_sl_jl.txt")
# # sd_afi = np.loadtxt(path+"sden_aferropumpT5J15_sl_jl.txt")
# # sd_sl = np.loadtxt(path+"sden_slpumpT5J15_sl_jl.txt")
# # ### Entropy
# ent_ferro = np.loadtxt(path+"entropy_ferropumpT5J15t100_sl_jl.txt")
# ent_afi = np.loadtxt(path+"entropy_aferropumpT5J15t100_sl_jl.txt")
# ent_sl = np.loadtxt(path+"entropy_slpumpT5J15t100_sl_jl.txt")

# %%
# ### Charge current
# cc_ferro = np.loadtxt(path+"cc_ferropumpT5Jsd01J01t100_sl_jl.txt")
# cc_afi  = np.loadtxt(path+"cc_aferropumpT5Jsd01J01t100_sl_jl.txt")
# cc_sl = np.loadtxt(path+"cc_slpumpT5Jsd01J01t100_sl_jl.txt")
# # ### Spin current 
# sc_ferro= np.loadtxt(path+"sc_ferropumpT5Jsd01J01t100_sl_jl.txt")
# sc_afi= np.loadtxt(path+"sc_aferropumpT5Jsd01J01t100_sl_jl.txt")
# sc_sl= np.loadtxt(path+"sc_slpumpT5Jsd01J01t100_sl_jl.txt")
# # ### Spin density 
# # sd_ferro = np.loadtxt(path+"sden_ferropumpT5J15_sl_jl.txt")
# # sd_afi = np.loadtxt(path+"sden_aferropumpT5J15_sl_jl.txt")
# # sd_sl = np.loadtxt(path+"sden_slpumpT5J15_sl_jl.txt")
# # ### Entropy
# ent_ferro = np.loadtxt(path+"entropy_ferropumpT5Jsd01J01t100_sl_jl.txt")
# ent_afi = np.loadtxt(path+"entropy_aferropumpT5Jsd01J01t100_sl_jl.txt")
# ent_sl = np.loadtxt(path+"entropy_slpumpT5Jsd01J01t100_sl_jl.txt")

# %%
fig,axes=plt.subplots(3,3,figsize=(15,15))
axs=np.reshape(axes,9)
fs=25

axs[0].set_title(r"$\rm{FI}$",fontsize=fs)
axs[0].set_ylabel(r'$\mathrm{I^{S_{\alpha} }_R\ (e\gamma/ h)}$',fontsize=fs)
#axs[0].plot(sc_ferro[:,0], sc_ferro[:,1],label=r'$\alpha=x$')
#axs[0].plot(sc_ferro[:,0], sc_ferro[:,2],label=r'$\alpha=y$')
axs[0].plot(sc_ferro[:,0], sc_ferro[:,3],color='red',label=r'$\alpha=z$')
axs[0].plot(cc_ferro[:,0], cc_ferro[:,1],color='black',alpha=0.6,label=r'$\alpha=c$')
#axs[0].plot(cc_ferro[:,0], cc_ferro[:,2])
##axs[0].set_ylim([-1.3,1.3])
#axs[0].set_xlim([100,200])
axs[0].set_xlim([0.,100])
###########----------------------------------------------###############
axs[1].set_title(r"$\rm{AFI}$",fontsize=fs)
#axs[1].set_ylabel(r'$\mathrm{I^{S_{\alpha} }_R\ (e\gamma/ h)}$',fontsize=fs)
#axs[1].plot(sc_afi[:,0], sc_afi[:,1],label=r'$\alpha=x$')
#axs[1].plot(sc_afi[:,0], sc_afi[:,2],label=r'$\alpha=y$')
axs[1].plot(sc_afi[:,0], sc_afi[:,3],color='red',label=r'$\alpha=z$')
axs[1].plot(cc_afi[:,0], cc_afi[:,1],color='black',alpha=0.6,label=r'$\alpha=c$')
axs[1].set_xlim([0.,100])
##axs[1].set_ylim([-2.3,2.3])
###########----------------------------------------------###############
axs[2].set_title(r"$\rm{QSL}$",fontsize=fs)
#axs[2].plot(sc_sl[:,0], sc_sl[:,1],label=r'$\alpha=x$')
#axs[2].plot(sc_sl[:,0], sc_sl[:,2],label=r'$\alpha=y$')
axs[2].plot(sc_sl[:,0], sc_sl[:,3],color='red',label=r'$\alpha=z$')
axs[2].plot(cc_sl[:,0], cc_sl[:,1],color='black',alpha=0.6,label=r'$\alpha=c$')
axs[2].set_xlim([0.,100])
##axs[2].set_ylim([-2.3,2.3])
###########----------------------------------------------###############
#axs[3].plot(ent_ferro[:,0],ent_ferro[:,1])
axs[3].set_ylabel(r'$\mathrm{Entropy}$',fontsize=fs)
axs[3].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
#axs[2].plot(ent_afi[:,0],ent_afi[:,1])
axs[3].plot(ent_ferro[:,0],ent_ferro[:,1])
###########----------------------------------------------###############
#axs[4].plot(ent_afi[:,0],ent_afi[:,1])
# axs[4].set_ylabel(r'$\mathrm{Entropy}$',fontsize=fs)
# axs[4].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axs[4].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axs[4].plot(ent_afi[:,0],ent_afi[:,1])
###########----------------------------------------------###############
axs[5].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axs[5].plot(ent_sl[:,0],ent_sl[:,1])
###########----------------------------------------------###############
axs[2].set_xlim([0.,200])
axs[3].set_xlim([0.,200])
axs[4].set_xlim([0.,200])
axs[5].set_xlim([0.,200])
axs[6].set_xlim([0.,200])
axs[7].set_xlim([0.,200])
axs[8].set_xlim([0.,200])
axs[0].axvline(50,color='black',ls=':',lw=2, alpha=1.0)
axs[1].axvline(50,color='black',ls=':',lw=2, alpha=1.0)
axs[2].axvline(50,color='black',ls=':',lw=2, alpha=1.0)
###########----------------------------------------------###############
axs[6].set_ylabel(r'$\mathrm{FFT \  \ I^{S_{\alpha} }_R}$',fontsize=fs)
#axs[6].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
axs[6].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
W1,F1 = fourier_transform(sc_ferro[:,0], sc_ferro[:,3], 0.1)
W2,F2 = fourier_transform(cc_ferro[:,0], cc_ferro[:,1], 0.1)
W1 = W1[::1]##*5#/(2*np.pi)#*T1 
W2 = W2[::1]*5#/(2*np.pi)#*T1 
axs[6].plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5)
axs[6].plot(W2[::1],F2[::1]**2,color='black',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5,alpha=0.6)
axs[6].set_xlim([0,8])
#axs[6].set_ylim([-1.5e-5,5e-3])
###########----------------------------------------------###############
#axs[7].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
axs[7].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
W1,F1 = fourier_transform(sc_afi[:,0], sc_afi[:,3], 0.1)
W2,F2 = fourier_transform(cc_afi[:,0], cc_afi[:,1], 0.1)
W1 = W1[::1]##*5#/(2*np.pi)#*T1 
W2 = W2[::1]##*5#/(2*np.pi)#*T1 
axs[7].plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black',label ="mode 1",lw=3,mfc='white',ms=2)
axs[7].plot(W2[::1],F2[::1]**2,color='black',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5,alpha=0.6)
axs[7].set_xlim([0,1e-1])
#axs[7].set_ylim([-1e-4,1e-2])
#axs[7].set_yscale("log")
###########----------------------------------------------###############
#axs[8].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
axs[8].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
W1,F1 = fourier_transform(sc_sl[:,0], sc_sl[:,3], 0.1)
W2,F2 = fourier_transform(cc_sl[:,0], cc_sl[:,1], 0.1)
W1 = W1[::1]##*5#/(2*np.pi)#*T1 
W2 = W2[::1]##*5#/(2*np.pi)#*T1 
axs[8].plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black',label ="mode 1",lw=3,mfc='white',ms=2)
axs[8].plot(W2[::1],F2[::1]**2,color='black',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5,alpha=0.6)
axs[8].set_xlim([0,6])
#axs[8].set_ylim([-1e-4,0.5e-2])
axs[0].legend(frameon=False,fontsize=fs-6,loc= (0.02,  0.05) )
###########----------------------------------------------###############
index=[r'$\rm{(a)}$',r'$\rm{(b)}$',r'$\rm{(c)}$',r'$\rm{(d)}$',r'$\rm{(e)}$',r'$\rm{(f)}$'
       ,r'$\rm{(g)}$',r'$\rm{(h)}$',r'$\rm{(j)}$',r'$\rm{(q)}$']#['(a)','(b)','(c)','(d)']
i=0
for ax in axs:
    
    axbox = ax.get_position()
    #ax.set_xlim([2,4])
    ax.text(x=0.9, y=0.9, s=index[i],fontsize=fs,ha='center', transform=ax.transAxes)
    ax.yaxis.set_major_locator(plt.MaxNLocator(4,integer=True))
    #ax.axvline(50,color='black',ls=':',lw=2, alpha=1.0)
    ax.xaxis.set_major_locator(plt.MaxNLocator(8,integer=True))
    ax.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
    ax.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=True)
    ax.yaxis.offsetText.set_fontsize(fs)
    i=i+1
plt.tight_layout()

# %%
fig,axes=plt.subplots(3,3,figsize=(18,15))
axs=np.reshape(axes,9)
fs=25

axs[0].set_title(r"$\rm{FI}$",fontsize=fs)
axs[0].set_ylabel(r'$\mathrm{I^{S_{\alpha} }_R\ (e\gamma/ h)}$',fontsize=fs)
#axs[0].plot(sc_ferro[:,0], sc_ferro[:,1],label=r'$\alpha=x$')
#axs[0].plot(sc_ferro[:,0], sc_ferro[:,2],label=r'$\alpha=y$')
axs[0].plot(sc_ferro[:,0], sc_ferro[:,3],color='red',label=r'$\alpha=z$')
axs[0].plot(cc_ferro[:,0], cc_ferro[:,1],color='black',alpha=0.6,label=r'$\alpha=c$')
#axs[0].plot(cc_ferro[:,0], cc_ferro[:,2])
##axs[0].set_ylim([-1.3,1.3])
#axs[0].set_xlim([100,200])
axs[0].set_xlim([0.,200])
###########----------------------------------------------###############
axs[1].set_title(r"$\rm{AFI}$",fontsize=fs)
#axs[1].set_ylabel(r'$\mathrm{I^{S_{\alpha} }_R\ (e\gamma/ h)}$',fontsize=fs)
# axs[1].plot(sc_afi[:,0], sc_afi[:,1],label=r'$\alpha=x$')
# axs[1].plot(sc_afi[:,0], sc_afi[:,2],label=r'$\alpha=y$')
axs[1].plot(sc_afi[:,0], sc_afi[:,3],color='red',label=r'$\alpha=z$')
axs[1].plot(cc_afi[:,0], cc_afi[:,1],color='black',alpha=0.6,label=r'$\alpha=c$')
axs[1].set_xlim([0.,200])
##axs[1].set_ylim([-2.3,2.3])
###########----------------------------------------------###############
axs[2].set_title(r"$\rm{QSL}$",fontsize=fs)
axs[2].plot(sc_sl[:,0], sc_sl[:,3],color='red',label=r'$\alpha=z$')
axs[2].plot(cc_sl[:,0], cc_sl[:,1],color='black',alpha=0.6,label=r'$\alpha=c$')
axs[2].set_xlim([0.,200])
##axs[2].set_ylim([-2.3,2.3])
###########----------------------------------------------###############
#axs[3].plot(ent_ferro[:,0],ent_ferro[:,1])
axs[3].set_ylabel(r'$\mathrm{Entropy}$',fontsize=fs)
axs[3].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
#axs[2].plot(ent_afi[:,0],ent_afi[:,1])
axs[3].plot(ent_ferro[:,0],ent_ferro[:,1])
###########----------------------------------------------###############
#axs[4].plot(ent_afi[:,0],ent_afi[:,1])
# axs[4].set_ylabel(r'$\mathrm{Entropy}$',fontsize=fs)
# axs[4].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axs[4].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axs[4].plot(ent_afi[:,0],ent_afi[:,1])
###########----------------------------------------------###############
axs[5].set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axs[5].plot(ent_sl[:,0],ent_sl[:,1])
###########----------------------------------------------###############
axs[2].set_xlim([0.,200])
axs[3].set_xlim([0.,100])
axs[4].set_xlim([0.,200])
axs[5].set_xlim([0.,200])
axs[6].set_xlim([0.,200])
axs[7].set_xlim([0.,200])
axs[8].set_xlim([0.,200])
##axs[0].axvline(50,color='black',ls=':',lw=2, alpha=1.0)
##axs[1].axvline(50,color='black',ls=':',lw=2, alpha=1.0)
##axs[2].axvline(50,color='black',ls=':',lw=2, alpha=1.0)
###########----------------------------------------------###############
axs[6].set_ylabel(r'$\mathrm{FFT \  \ I^{S_{\alpha} }_R}$',fontsize=fs)
#axs[6].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
#axs[6].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
W1,F1 = fourier_transform(sc_ferro[:,0], sc_ferro[:,3], 0.1)
W2,F2 = fourier_transform(cc_ferro[:,0], cc_ferro[:,1], 0.1)
W1 = W1[::1]*5#/(2*np.pi)#*T1 
W2 = W2[::1]*5#/(2*np.pi)#*T1 
axs[6].plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5)
axs[6].plot(W2[::1],F2[::1]**2,color='black',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5,alpha=0.6)
#axs[6].set_xlim([0,8])
axs[6].set_xlim([0,15])
#axs[6].set_ylim([-1.5e-3,0.3e-1])
axs[6].set_yscale("log")
###########----------------------------------------------###############
#axs[7].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
#axs[7].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
W1,F1 = fourier_transform(sc_afi[:,0], sc_afi[:,3], 0.1)
W2,F2 = fourier_transform(cc_afi[:,0], cc_afi[:,1], 0.1)
W1 = W1[::1]*5#/(2*np.pi)#*T1 
W2 = W2[::1]*5#/(2*np.pi)#*T1 
axs[7].plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black',label ="mode 1",lw=3,mfc='white',ms=2)
axs[7].plot(W2[::1],F2[::1]**2,color='black',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5,alpha=0.6)
#axs[7].set_xlim([0,6])
axs[7].set_xlim([0,15])
#axs[7].set_ylim([-1e-2,1.5e-1])
axs[7].set_yscale("log")
###########----------------------------------------------###############
#axs[8].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
#axs[8].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
axs[6].set_xlabel(r'$\omega$',fontsize=fs+5)
axs[7].set_xlabel(r'$\omega$',fontsize=fs+5)
axs[8].set_xlabel(r'$\omega$',fontsize=fs+5)
W1,F1 = fourier_transform(sc_sl[:,0], sc_sl[:,3], 0.1)
W2,F2 = fourier_transform(cc_sl[:,0], cc_sl[:,1], 0.1)
W1 = W1[::1]*5#/(2*np.pi)#*T1 
W2 = W2[::1]*5#/(2*np.pi)#*T1 
axs[8].plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black',label ="mode 1",lw=3,mfc='white',ms=2)
axs[8].plot(W2[::1],F2[::1]**2,color='black',ls ='--',markeredgecolor ='black' ,label ="mode 1",lw=3,mfc='white',ms=5,alpha=0.6)
axs[8].set_xlim([0,15])
#axs[8].set_ylim([-1e-3,1.5e-2])
axs[8].set_yscale("log")
axs[0].legend(frameon=False,fontsize=fs-6,loc= (0.6,  0.2) )
###########----------------------------------------------###############
index=[r'$\rm{(a)}$',r'$\rm{(b)}$',r'$\rm{(c)}$',r'$\rm{(d)}$',r'$\rm{(e)}$',r'$\rm{(f)}$'
       ,r'$\rm{(g)}$',r'$\rm{(h)}$',r'$\rm{(j)}$',r'$\rm{(q)}$']#['(a)','(b)','(c)','(d)']
axs[0].set_ylim([-1e-3,1e-3])
axs[1].set_ylim([-1e-3,1e-3])
axs[2].set_ylim([-1e-3,1e-3])
axs[0].axhline(0,color='black',ls=':',lw=2, alpha=1.0)
axs[1].axhline(0,color='black',ls=':',lw=2, alpha=1.0)
axs[2].axhline(0,color='black',ls=':',lw=2, alpha=1.0)
i=0
for ax in axs:
    
    axbox = ax.get_position()
    #ax.set_xlim([2,4])
    ax.text(x=0.1, y=0.9, s=index[i],fontsize=fs,ha='center', transform=ax.transAxes)
    #ax.yaxis.set_major_locator(plt.MaxNLocator(4,integer=True))
    #ax.axhline(0,color='black',ls=':',lw=2, alpha=1.0)
    ax.xaxis.set_major_locator(plt.MaxNLocator(8,integer=True))
    ax.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
    ###ax.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=True)
    ax.yaxis.offsetText.set_fontsize(fs)
    i=i+1
plt.tight_layout()

# %%
fig,axes=plt.subplots(1,1,figsize=(7,7))
#axs=np.reshape(axes,2)

###########----------------------------------------------###############
axes.set_ylabel(r'$\mathrm{Entropy}$',fontsize=fs)
axes.set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axes.plot(ent_ferro[:,0],ent_ferro[:,1]*10,color="blue",label=r"$\rm{FI}$")
###########----------------------------------------------###############
axes.set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axes.plot(ent_afi[:,0],ent_afi[:,1],color="orange",ms=5,label=r"$\rm{AFI}$")
###########----------------------------------------------###############
axes.set_xlabel(r'$\mathrm{Time\ (fs)}$',fontsize=fs)
axes.plot(ent_sl[:,0],ent_sl[:,1],color="green",label=r"$\rm{QSL}$")
axes.set_xlim([0,100])
###########----------------------------------------------###############
index=[r'$\rm{(a)}$',r'$\rm{(b)}$',r'$\rm{(c)}$',r'$\rm{(d)}$',r'$\rm{(e)}$',r'$\rm{(f)}$'
       ,r'$\rm{(g)}$',r'$\rm{(h)}$',r'$\rm{(j)}$',r'$\rm{(q)}$']#['(a)','(b)','(c)','(d)']


# axs[1].set_ylabel(r'$\mathrm{FFT \  \ Entropy }$',fontsize=fs)
# #axs[6].set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
# ##axs[3].plot(ent_ferro[:,0],ent_ferro[:,1])
# axs[1].set_xlabel(r'$\frac{\mathrm{\omega}}{\mathrm{\omega_0}}$',fontsize=fs+5)
# W1,F1 = fourier_transform(ent_ferro[:,0], ent_ferro[:,1], 0.1)
# W2,F2 = fourier_transform(ent_afi[:,0], ent_afi[:,1], 0.1)
# W3,F3 = fourier_transform(ent_sl[:,0], ent_sl[:,1], 0.1)
# W1 = W1[::1]*5#/(2*np.pi)#*T1 
# W2 = W2[::1]*5#/(2*np.pi)#*T1 
# W3 = W3[::1]*5#/(2*np.pi)#*T1 
# axs[1].plot(W1[::1],F1[::1]**2,color='blue',ls ='--',markeredgecolor ='black' ,lw=3,mfc='white',ms=5)
# axs[1].plot(W2[::1],F2[::1]**2,color='orange',ls ='--',markeredgecolor ='black',lw=3,mfc='white')
# axs[1].plot(W3[::1],F3[::1]**2,color='green',ls ='--',markeredgecolor ='black' ,lw=3,mfc='white',ms=5)
# axs[1].set_xlim([0,0.5])


axes.legend(frameon=False,fontsize=fs-4,loc= (0.7,  0.3) )



axbox = axes.get_position()
##axes.text(x=0.1, y=0.9, s=index[i],fontsize=fs,ha='center', transform=ax.transAxes)
axes.yaxis.set_major_locator(plt.MaxNLocator(4,integer=True))
#ax.axvline(50,color='black',ls=':',lw=2, alpha=1.0)
axes.xaxis.set_major_locator(plt.MaxNLocator(4,integer=True))
axes.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
###ax.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=True)
axes.yaxis.offsetText.set_fontsize(fs)
# i=0
# for ax in axes:
#     axbox = ax.get_position()
#     ax.text(x=0.1, y=0.9, s=index[i],fontsize=fs,ha='center', transform=ax.transAxes)
#     ax.yaxis.set_major_locator(plt.MaxNLocator(4,integer=True))
#     #ax.axvline(50,color='black',ls=':',lw=2, alpha=1.0)
#     ax.xaxis.set_major_locator(plt.MaxNLocator(4,integer=True))
#     ax.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
#     ###ax.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=True)
#     ax.yaxis.offsetText.set_fontsize(fs)
#     i=i+1
plt.tight_layout()

# %%
fig,axs=plt.subplots(1,1,figsize=(7,7))

#axs[0].plot(sc_ferro[:,0], sc_ferro[:,3],color='red',label=r'$\alpha=z$')
#axs[0].plot(cc_ferro[:,0], cc_ferro[:,1]*10,color='black',alpha=0.6,label=r'$\alpha=c$')
W1,F1 = fourier_transform(sc_ferro[:,0], sc_ferro[:,3], 0.1)
W1 = W1[::1]*5/(2*np.pi)#*T1 
axs.set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
axs.set_ylabel(r'$\mathrm{FFT \  \ I^{S_{z} }_R}$',fontsize=fs)
axs.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
axs.yaxis.offsetText.set_fontsize(fs)
#plt.scatter(W1[::1],F1[::1]**2,marker='>',edgecolors='black',label=r'mode 1',color='white',s=80)
axs.plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black',marker='o' ,label ="mode 1",lw=3,mfc='white',ms=5)
axs.set_xlim([0,2])
# Out:
# (0.0, 2.0)

# %%
fig,axs=plt.subplots(1,1,figsize=(7,7))

axs.set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
axs.set_ylabel(r'$\mathrm{FFT \ \ I_R }$',fontsize=fs)
axs.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
axs.yaxis.offsetText.set_fontsize(fs)

W1,F1 = fourier_transform(cc_ferro[:,0], cc_ferro[:,1], 0.1)
W1 = W1[::1]*5/(2*np.pi)#/2*np.pi#*T1 
#plt.scatter(W1[::1],F1[::1]**2,marker='>',edgecolors='black',label=r'mode 1',color='white',s=80)
plt.plot(W1[::1],F1[::1]**2,color='black',ls ='--',markeredgecolor ='black',marker='o' ,label ="mode 1",lw=3,mfc='white',ms=2)
plt.xlim([0,2])
# Out:
# (0.0, 2.0)

# %%
fig,axs=plt.subplots(1,1,figsize=(7,7))

W1,F1 = fourier_transform(ent_afi[:,0],ent_afi[:,1], 0.1)
W1 = W1[::1]#*T1 
axs.set_xlabel(r'$\mathrm{Frequency\ (THz)}$',fontsize=fs)
axs.set_ylabel(r'$\mathrm{FFT \  \ Entropy}$',fontsize=fs)
axs.tick_params(axis='both', which='both', labelsize=fs,direction='in', length=6)
axs.yaxis.offsetText.set_fontsize(fs)
#plt.scatter(W1[::1],F1[::1]**2,marker='>',edgecolors='black',label=r'mode 1',color='white',s=80)
axs.plot(W1[::1],F1[::1]**2,color='red',ls ='--',markeredgecolor ='black',marker='o' ,label ="mode 1",lw=3,mfc='white',ms=5)
axs.set_xlim([0,0.5])
# Out:
# (0.0, 0.5)
